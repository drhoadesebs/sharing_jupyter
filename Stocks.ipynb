# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
tickerSymbol=%env TICKER_SYMBOL

# %%
tickerData=yf.Ticker(tickerSymbol)

# %%
tickerDF = tickerData.history(period="max")

# %%
tickerDF.to_csv(tickerSymbol + '.csv')

# %% [markdown]
# # FINANCIAL SUMMARY REPORT

# %%
print('         REPORT FOR STOCK: ' + tickerSymbol)
# Out:
#          REPORT FOR STOCK: MSFT

# %% [markdown]
# ## Last 20 Days

# %%
tickerDF.tail(20)
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-01-23  165.74  166.35  164.82  166.27  19680800       0.00           0.0
# 2020-01-24  167.05  167.07  164.00  164.59  24918100       0.00           0.0
# 2020-01-27  160.71  162.93  159.76  161.84  32078100       0.00           0.0
# 2020-01-28  163.33  165.31  162.63  165.01  24899900       0.00           0.0
# 2020-01-29  167.38  168.29  165.24  167.58  34754500       0.00           0.0
# 2020-01-30  173.58  173.58  170.32  172.31  51597500       0.00           0.0
# 2020-01-31  171.74  171.93  169.12  169.77  36142700       0.00           0.0
# 2020-02-03  169.97  174.02  169.94  173.90  30149100       0.00           0.0
# 2020-02-04  176.66  180.15  175.83  179.63  36433300       0.00           0.0
# 2020-02-05  183.53  183.70  177.92  179.41  39186300       0.00           0.0
# 2020-02-06  180.48  183.32  179.57  183.13  27751400       0.00           0.0
# ...

# %% [markdown]
# ## Closing Price over the Years

# %%
x=tickerDF.index
y=tickerDF.Close
def plot(x, y, ax, title, y_label):
    ax.set_title(title)
    ax.set_ylabel(y_label)
    ax.plot(x, y)
    ax.margins(x=0, y=0)
fig, ax = plt.subplots()
plot(x, y, ax, 'History of Closing Price: '+ tickerSymbol, 'Closing Price')

# %% [markdown]
# ## General Company Information & Financial Ratios

# %%
tickerData.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %% [markdown]
# ## Earnings Schedule and Estimates

# %%
tickerData.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-04-22 00:00:00  2020-04-27 00:00:00
# Earnings Average                 1.33                 1.33
# Earnings Low                      1.3                  1.3
# Earnings High                    1.43                 1.43
# Revenue Average           34606800000          34606800000
# Revenue Low               34325200000          34325200000
# Revenue High              35111000000          35111000000

# %% [markdown]
# ## Stock Recommendations

# %%
tickerData.recommendations
# Out:
#                           Firm        To Grade From Grade Action
# Date
# 2012-07-20  Griffin Securities             Buy              init
# 2012-07-20       Goldman Sachs         Neutral              main
# 2012-08-20    Longbow Research             Buy              init
# 2012-09-12           Jefferies            Hold              init
# 2012-10-01         RBC Capital  Sector Perform              down
# ...                        ...             ...        ...    ...
# 2019-12-17       Deutsche Bank             Buy              main
# 2020-01-08      Morgan Stanley      Overweight              main
# 2020-01-09             Wedbush      Outperform              main
# 2020-01-09         Cowen & Co.      Outperform              main
# 2020-01-10           Jefferies             Buy              main
#
# [226 rows x 4 columns]

# %% [markdown]
# ## Major Holders of Stock & Float

# %%
tickerData.major_holders
# Out:
#         0                                      1
# 0   1.42%        % of Shares Held by All Insider
# 1  75.18%       % of Shares Held by Institutions
# 2  76.26%        % of Float Held by Institutions
# 3    4505  Number of Institutions Holding Shares

# %% [markdown]
# ## Institutional Investors

# %%
tickerData.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  623667281    2019-12-30  0.0820
# 1                     Blackrock Inc.  515197221    2019-12-30  0.0677
# 2           State Street Corporation  315672520    2019-12-30  0.0415
# 3                           FMR, LLC  239124143    2019-12-30  0.0314
# 4            Capital World Investors  180450388    2019-09-29  0.0237
# 5      Price (T.Rowe) Associates Inc  175036277    2019-12-30  0.0230
# 6      Geode Capital Management, LLC  113401519    2019-12-30  0.0149
# 7    Capital International Investors   98941506    2019-09-29  0.0130
# 8         Northern Trust Corporation   93192050    2019-12-30  0.0123
# 9  Capital Research Global Investors   92893893    2019-09-29  0.0122
#
#          Value
# 0  98352330213
# 1  81246601751
# 2  49781556404
# 3  37709877351
# 4  25088017443
# 5  27603220882
# 6  17883419546
# 7  13755837579
# 8  14696386285
# 9  12915037943

# %% [markdown]
# ## Sustainability Info

# %%
tickerData.sustainability
# Out:
#                                      Value
# 2020-1
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           9.71
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                         0
# peerCount                               98
# governanceScore                       5.19
# environmentPercentile                    0
# animalTesting                        False
# tobacco                              False
# totalEsg                             15.35
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...
