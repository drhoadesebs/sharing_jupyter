# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
tickerSymbol="AMZN"

# %%
tickerData=yf.Ticker(tickerSymbol)

# %%
tickerDF = tickerData.history(period="max")

# %%
tickerDF.to_csv(tickerSymbol + '.csv')

# %%
tickerDF
# Out:
#                Open     High      Low    Close    Volume  Dividends  \
# Date
# 1997-05-15     2.44     2.50     1.93     1.96  72156000          0
# 1997-05-16     1.97     1.98     1.71     1.73  14700000          0
# 1997-05-19     1.76     1.77     1.62     1.71   6106800          0
# 1997-05-20     1.73     1.75     1.64     1.64   5467200          0
# 1997-05-21     1.64     1.65     1.38     1.43  18853200          0
# ...             ...      ...      ...      ...       ...        ...
# 2020-02-12  2163.20  2180.25  2155.29  2160.00   3334300          0
# 2020-02-13  2144.99  2170.28  2142.00  2149.87   3031800          0
# 2020-02-14  2155.68  2159.04  2125.89  2134.87   2606200          0
# 2020-02-18  2125.02  2166.07  2124.11  2155.67   2945600          0
# 2020-02-19  2167.80  2185.04  2161.23  2179.20   1998602          0
#
#             Stock Splits
# Date
# 1997-05-15           0.0
# 1997-05-16           0.0
# 1997-05-19           0.0
# 1997-05-20           0.0
# 1997-05-21           0.0
# ...                  ...
# 2020-02-12           0.0
# 2020-02-13           0.0
# 2020-02-14           0.0
# 2020-02-18           0.0
# 2020-02-19           0.0
#
# [5728 rows x 7 columns]

# %%
x=tickerDF.index
y=tickerDF.Close
def plot(x, y, ax, title, y_label):
    ax.set_title(title)
    ax.set_ylabel(y_label)
    ax.plot(x, y)
    ax.margins(x=0, y=0)
fig, ax = plt.subplots()
plot(x, y, ax, 'History of Closing Price: '+ tickerSymbol, 'Closing Price')

# %%
tickerData.info
# Out:
# {'zip': '98109-5210',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 798000,
#  'longBusinessSummary': 'Amazon.com, Inc. engages in the retail sale of consumer products and subscriptions in North America and internationally. The company operates through three segments: North America, International, and Amazon Web Services (AWS). It sells merchandise and content purchased for resale from third-party sellers through physical and online stores. The company also manufactures and sells electronic devices, including Kindle, Fire tablets, Fire TVs, Rings, and Echo and other devices; provides Kindle Direct Publishing, an online service that allows independent authors and publishers to make their books available in the Kindle Store; and develops and produces media content. In addition, it offers programs that enable sellers to sell their products on its Websites, as well as its stores; and programs that allow authors, musicians, filmmakers, skill and app developers, and others to publish and sell content. Further, the company provides compute, storage, database, and other AWS services, as well as fulfillment, advertising, publishing, and digital content subscriptions. Additionally, it offers Amazon Prime, a membership program, which provides free shipping of various items; access to streaming of movies and TV episodes; and other services. It serves consumers, sellers, developers, enterprises, and content creators. The company was founded in 1994 and is headquartered in Seattle, Washington.',
#  'city': 'Seattle',
#  'phone': '206-266-1000',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.amazon.com',
#  'maxAge': 1,
#  'address1': '410 Terry Avenue North',
#  'industry': 'Internet Retail',
#  'previousClose': 2155.67,
#  'regularMarketOpen': 2167.8,
#  'twoHundredDayAverage': 1821.5531,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2185.0376,
#  'navPrice': None,
#  'averageDailyVolume10Day': 3786683,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 2155.67,
#  'fiftyDayAverage': 1955.3091,
#  'trailingAnnualDividendRate': None,
#  'open': 2167.8,
#  'averageVolume10days': 3786683,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': 1.615724,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2161.23,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 94.70665,
#  'regularMarketVolume': 1998607,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1084827500544,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 3626722,
#  'priceToSalesTrailing12Months': 3.8671744,
#  'dayLow': 2161.23,
#  'ask': 2178.92,
#  'ytdReturn': None,
#  'askSize': 800,
#  'volume': 1998607,
#  'fiftyTwoWeekHigh': 2185.95,
#  'forwardPE': 54.208954,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 1586.57,
#  'bid': 2177.82,
#  'tradeable': True,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 2185.0376,
#  'exchange': 'NMS',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AMZN',
#  'messageBoardId': 'finmb_18749',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 3.869,
#  'beta3Year': None,
#  'profitMargins': 0.04131,
#  'enterpriseToEbitda': 29.986,
#  '52WeekChange': 0.32446325,
#  'morningStarRiskRating': None,
#  'forwardEps': 40.2,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 498000000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 124.618,
#  'sharesShort': 3521884,
#  'sharesPercentSharesOut': 0.0070999996,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1577750400,
#  'heldPercentInstitutions': 0.58353,
#  'netIncomeToCommon': 11587999744,
#  'trailingEps': 23.01,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.21243918,
#  'priceToBook': 17.487041,
#  'heldPercentInsiders': 0.15158,
#  'nextFiscalYearEnd': 1640908800,
#  'mostRecentQuarter': 1577750400,
#  'shortRatio': 0.89,
#  'sharesShortPreviousMonthDate': 1577750400,
#  'floatShares': 421988935,
#  'enterpriseValue': 1085274587136,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 936230400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.08,
#  'dateShortInterest': 1580428800,
#  'pegRatio': 2.49,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0085,
#  'sharesShortPriorMonth': 4161073,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 2167.8,
#  'logo_url': 'https://logo.clearbit.com/amazon.com'}

# %%
tickerData.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-04-23 00:00:00  2020-04-27 00:00:00
# Earnings Average                 6.43                 6.43
# Earnings Low                     5.62                 5.62
# Earnings High                    7.88                 7.88
# Revenue Average           72281000000          72281000000
# Revenue Low               70279300000          70279300000
# Revenue High              73453000000          73453000000

# %%
tickerData.recommendations
# Out:
#                          Firm        To Grade From Grade Action
# Date
# 2012-07-11        BMO Capital  Market Perform              init
# 2012-07-17             Lazard             Buy              init
# 2012-07-27      Deutsche Bank             Buy              main
# 2012-07-27        Oppenheimer      Outperform              main
# 2012-08-31       PiperJaffray      Overweight              main
# ...                       ...             ...        ...    ...
# 2019-10-25        BMO Capital      Outperform              main
# 2019-10-25      Raymond James      Outperform              main
# 2019-10-25      Piper Jaffray      Overweight              main
# 2019-11-26  China Renaissance            Hold              init
# 2020-01-10          Bernstein  Market Perform              init
#
# [302 rows x 4 columns]

# %%
tickerData.major_holders
# Out:
#         0                                      1
# 0  15.16%        % of Shares Held by All Insider
# 1  58.35%       % of Shares Held by Institutions
# 2  68.78%        % of Float Held by Institutions
# 3    3894  Number of Institutions Holding Shares

# %%
tickerData.institutional_holders
# Out:
#                               Holder    Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  32064108    2019-12-30  0.0644
# 1                     Blackrock Inc.  26707477    2019-12-30  0.0536
# 2           State Street Corporation  16906057    2019-12-30  0.0340
# 3                           FMR, LLC  15654807    2019-12-30  0.0314
# 4      Price (T.Rowe) Associates Inc  15000013    2019-12-30  0.0301
# 5      Geode Capital Management, LLC   5901043    2019-12-30  0.0119
# 6         Northern Trust Corporation   4842269    2019-12-30  0.0097
# 7                     Morgan Stanley   4519757    2019-09-29  0.0091
# 8        Baillie Gifford and Company   4493110    2019-12-30  0.0090
# 9  Norges Bank Investment Management   4347576    2018-12-30  0.0087
#
#          Value
# 0  59249341326
# 1  49351144299
# 2  31239688366
# 3  28927578566
# 4  27717624021
# 5  10904183297
# 6   8947738348
# 7   7845891373
# 8   8302548382
# 9   6529928724

# %%
tickerData.sustainability
# Out:
#                            Value
# 2020-1
# palmOil                    False
# controversialWeapons       False
# gambling                   False
# socialScore                13.74
# nuclear                    False
# furLeather                 False
# alcoholic                  False
# gmo                        False
# catholic                   False
# socialPercentile               0
# peerCount                     60
# governanceScore            11.01
# environmentPercentile          0
# animalTesting              False
# tobacco                    False
# totalEsg                   30.57
# highestControversy             3
# esgPerformance          OUT_PERF
# coal                       False
# pesticides                 False
# adult                      False
# percentile                 56.47
# peerGroup              Retailing
# smallArms                  False
# environmentScore            5.82
# governancePercentile           0
# militaryContract           False
